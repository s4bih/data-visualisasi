# %% [markdown]
# <a href="https://colab.research.google.com/github/s4bih/data-visualisasi/blob/main/terbang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights_url = 'https://drive.google.com/uc?id=13XxxA7DMXH64KtdHeqWH4W6_lOVrcmOV'
airports_url = 'https://drive.google.com/uc?id=1LhmE6VUZoArDDk4bYn8AEU3dnqomCGqR'
flight  = pd.read_csv(flights_url)
airport = pd.read_csv(airports_url)
flight
# Out:
#          DayofMonth  DayOfWeek Carrier  OriginAirportID  DestAirportID  \
# 0                19          5      DL            11433          13303
# 1                19          5      DL            14869          12478
# 2                19          5      DL            14057          14869
# 3                19          5      DL            15016          11433
# 4                19          5      DL            11193          12892
# ...             ...        ...     ...              ...            ...
# 2702213          19          6      DL            13204          14869
# 2702214          19          6      DL            10397          13495
# 2702215          19          6      DL            10140          10397
# 2702216          19          6      DL            10397          13244
# 2702217          19          6      DL            10397          13487
#
#          DepDelay  ArrDelay
# 0              -3         1
# 1               0        -8
# ...

# %%
airport
# Out:
#      airport_id          city state                                 name
# 0         10165   Adak Island    AK                                 Adak
# 1         10299     Anchorage    AK  Ted Stevens Anchorage International
# 2         10304         Aniak    AK                        Aniak Airport
# 3         10754        Barrow    AK      Wiley Post/Will Rogers Memorial
# 4         10551        Bethel    AK                       Bethel Airport
# ..          ...           ...   ...                                  ...
# 360       11233      Cheyenne    WY  Cheyenne Regional/Jerry Olson Field
# 361       11097          Cody    WY                 Yellowstone Regional
# 362       11865      Gillette    WY             Gillette Campbell County
# 363       12441       Jackson    WY                         Jackson Hole
# 364       14543  Rock Springs    WY       Rock Springs Sweetwater County
#
# [365 rows x 4 columns]

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2702218 entries, 0 to 2702217
# Data columns (total 7 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   DayofMonth       int64
#  1   DayOfWeek        int64
#  2   Carrier          object
#  3   OriginAirportID  int64
#  4   DestAirportID    int64
#  5   DepDelay         int64
#  6   ArrDelay         int64
# dtypes: int64(6), object(1)
# memory usage: 144.3+ MB

# %%
airport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   airport_id  365 non-null    int64
#  1   city        365 non-null    object
#  2   state       365 non-null    object
#  3   name        365 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 11.5+ KB

# %%
flight.describe()
# Out:
#          DayofMonth     DayOfWeek  OriginAirportID  DestAirportID  \
# count  2.702218e+06  2.702218e+06     2.702218e+06   2.702218e+06
# mean   1.579790e+01  3.899480e+00     1.274260e+04   1.274300e+04
# std    8.798835e+00  1.985925e+00     1.501841e+03   1.501801e+03
# min    1.000000e+00  1.000000e+00     1.014000e+04   1.014000e+04
# 25%    8.000000e+00  2.000000e+00     1.129200e+04   1.129200e+04
# 50%    1.600000e+01  4.000000e+00     1.289200e+04   1.289200e+04
# 75%    2.300000e+01  6.000000e+00     1.405700e+04   1.405700e+04
# max    3.100000e+01  7.000000e+00     1.537600e+04   1.537600e+04
#
#            DepDelay      ArrDelay
# count  2.702218e+06  2.702218e+06
# mean   1.051073e+01  6.655011e+00
# std    3.602976e+01  3.854758e+01
# min   -6.300000e+01 -9.400000e+01
# 25%   -4.000000e+00 -1.100000e+01
# 50%   -1.000000e+00 -3.000000e+00
# 75%    9.000000e+00  1.000000e+01
# max    1.863000e+03  1.845000e+03

# %%
airport.describe()

# %%
#SCATTER PLOt
plt.figure(figsize=(10,5))
sns.scatterplot( data = flight, x = 'ArrDelay', y = 'DepDelay')
plt.show()

# %%
airplot_flight = flight.merge(airport, right_on = 'airport_id', left_on = 'OriginAirportID',how = 'inner')
airplot_flight
# Out:
#          DayofMonth  DayOfWeek Carrier  OriginAirportID  DestAirportID  \
# 0                19          5      DL            11433          13303
# 1                19          5      DL            14869          12478
# 2                19          5      DL            14057          14869
# 3                19          5      DL            15016          11433
# 4                19          5      DL            11193          12892
# ...             ...        ...     ...              ...            ...
# 2702213          19          6      DL            13204          14869
# 2702214          19          6      DL            10397          13495
# 2702215          19          6      DL            10140          10397
# 2702216          19          6      DL            10397          13244
# 2702217          19          6      DL            10397          13487
#
#          DepDelay  ArrDelay  airport_id            city state  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = airplot_flight, x = 'Carrier', y = 'DepDelay')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = airplot_flight, x = 'state')
plt.show()
