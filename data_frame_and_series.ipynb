# %% [markdown]
# <a href="https://colab.research.google.com/github/s4bih/data-visualisasi/blob/main/data_frame_and_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #section 1

# %%
import pandas as pd
studentss = ["rio","udin","yanto","saipul"]

s1 = pd.Series(student)
print(s1  )
# Out:
# 0       rio
# 1      udin
# 2     yanto
# 3    saipul
# dtype: object

# %%
student = [
    ["rio", 15,"male"],
    ["udin", 14,"male"],
    ["yanto", 13,"male"],
    ["saipul", 21,"male"],
]

# %%
df = pd.DataFrame(student)
df
# Out:
#         0   1     2
# 0     rio  15  male
# 1    udin  14  male
# 2   yanto  13  male
# 3  saipul  21  male

# %%
df = pd.DataFrame(student, columns=["name","age","gender"])
df
# Out:
#      name  age gender
# 0     rio   15   male
# 1    udin   14   male
# 2   yanto   13   male
# 3  saipul   21   male

# %%
student = {
    "name":["rio","udin","yanto","saipul"],
    "age":[15,14,13,21],
    "gender":["male","male","male","male"]
}
print(student)
print(type(student))
# Out:
# {'name': ['rio', 'udin', 'yanto', 'saipul'], 'age': [15, 14, 13, 21], 'gender': ['male', 'male', 'male', 'male']}
# <class 'dict'>

# %%
df1=pd.DataFrame(student,index=['a','b','c','d'])
print(df1)

print(type(df1))
# Out:
#      name  age gender
# a     rio   15   male
# b    udin   14   male
# c   yanto   13   male
# d  saipul   21   male
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #section2

# %%
bulan = ["january","february","march","april","may","june"]
sales = [12000,13000,14000,15000,16000,17000]
d3={"bulan":bulan,"sales":sales}
d3=pd.DataFrame(d3)
d3
# Out:
#       bulan  sales
# 0   january  12000
# 1  february  13000
# 2     march  14000
# 3     april  15000
# 4       may  16000
# 5      june  17000

# %%
import pandas as pd

data = {'nama': ['agus', 'rio', 'roi', 'suga'],
        'grade': [8, 6, 10, 12],
        'sex': ['male', 'male', 'male', 'male']}

df = pd.DataFrame(data)

df
# Out:
#    nama  grade   sex
# 0  agus      8  male
# 1   rio      6  male
# 2   roi     10  male
# 3  suga     12  male

# %%
df.at[1,"nama"]
# Out:
# 'rio'

# %%
df.iat[3,1]
# Out:
# 12

# %%
df.dtypes
# Out:
# nama     object
# grade     int64
# sex      object
# dtype: object

# %%
df.iat[1,0]
# Out:
# 'rio'

# %% [markdown]
# #rever to index row

# %%
print(df.loc[0])
# Out:
# nama     agus
# grade       8
# sex      male
# Name: 0, dtype: object

# %%
print(df.loc[1:3])
# Out:
#    nama  grade   sex
# 1   rio      6  male
# 2   roi     10  male
# 3  suga     12  male

# %% [markdown]
# ##ilock method

# %%
df = pd.DataFrame(data,index=['a','b','c','d'])
print(df)
# Out:
#    nama  grade   sex
# a  agus      8  male
# b   rio      6  male
# c   roi     10  male
# d  suga     12  male

# %%
print(df.iloc[0])
# Out:
# nama     agus
# grade       8
# sex      male
# Name: a, dtype: object

# %%
print(df.loc["a"])
# Out:
# nama     agus
# grade       8
# sex      male
# Name: a, dtype: object
