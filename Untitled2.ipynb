# %% [markdown]
# <a href="https://colab.research.google.com/github/s4bih/data-visualisasi/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url_data = pd.read_html("https://www.worldometers.info/world-population/population-by-country/")
url_data[0]
# Out:
#        # Country (or dependency)  Population  (2024) Yearly  Change  \
# 0      1                   India          1450935791         0.89 %
# 1      2                   China          1419321278        -0.23 %
# 2      3           United States           345426571         0.57 %
# 3      4               Indonesia           283487931         0.82 %
# 4      5                Pakistan           251269164         1.52 %
# ..   ...                     ...                 ...            ...
# 229  230              Montserrat                4389        -0.70 %
# 230  231        Falkland Islands                3470        -0.20 %
# 231  232                 Tokelau                2506         4.55 %
# 232  233                    Niue                1819         0.11 %
# 233  234                Holy See                 496         0.00 %
#
#      Net  Change  Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  \
# 0       12866195               488           2973190          -630830
# ...

# %%
url_data[0].columns
# Out:
# Index(['#', 'Country (or dependency)', 'Population  (2024)', 'Yearly  Change',
#        'Net  Change', 'Density  (P/Km²)', 'Land Area  (Km²)',
#        'Migrants  (net)', 'Fert.  Rate', 'Med.  Age', 'Urban  Pop %',
#        'World  Share'],
#       dtype='object')

# %%
type(url_data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
url_data[0].dtypes
# Out:
# #                            int64
# Country (or dependency)     object
# Population  (2024)           int64
# Yearly  Change              object
# Net  Change                  int64
# Density  (P/Km²)             int64
# Land Area  (Km²)             int64
# Migrants  (net)              int64
# Fert.  Rate                float64
# Med.  Age                    int64
# Urban  Pop %                object
# World  Share                object
# dtype: object

# %%
dfi = url_data[0].to_csv("dfi.csv")
print("data saved")
# Out:
# data saved
